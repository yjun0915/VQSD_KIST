# %%
import numpy as np
import yaml

# %%
with open("../config/params.yaml", "r", encoding="utf-8") as f:
    config = yaml.safe_load(f)
print(config['devices']['slm'])
# Out:
# [[1920, 1080], '8e-6', '8e-4']
